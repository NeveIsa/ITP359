# %%
from cifar10_web import cifar10
from matplotlib import pyplot as plt

import numpy as np

import torch.nn as nn
import torch
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
# from kornia.filters import UnsharpMask


from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


import warnings 
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib")

# %%
X_train, train_labels, X_test, test_labels = cifar10(path=None)

X_train = X_train.reshape(-1,3,32,32)
X_test = X_test.reshape(-1,3,32,32)

mean = X_train.mean(axis=(0,2,3)).reshape(1,3,1,1)
std = X_train.std(axis=(0,2,3)).reshape(1,3,1,1)

X_train = (X_train - mean) / std 
X_test = (X_test - mean) /std 

X_train_noisy = X_train + np.random.randn(*X_train.shape)*0.2
X_test_noisy = X_test + np.random.randn(*X_test.shape)*0.2

X_train, X_test, X_train_noisy, X_test_noisy = map(torch.tensor, [X_train, X_test, X_train_noisy, X_test_noisy])

# X_train, X_test, X_train_noisy, X_test_noisy = map(lambda x:x.to(device), [X_train, X_test, X_train_noisy, X_test_noisy])

# %%
# _imgs = image_format(model(X_test[:100].to(device)))

plt.figure(figsize=(10,10))
for _imgid in range(100):
    plt.subplot(10,10,_imgid+1)    

    # plt.subplot(1,3,1)
    # plt.imshow(image_format(X_test[_imgid].reshape(1,3,32,32))[0])

    # plt.subplot(1,3,2)
    plt.imshow(image_format(X_train[_imgid].reshape(1,3,32,32))[0])

    # plt.subplot(10,3,3)
    # plt.imshow(imgs[_imgid]/imgs[_imgid].max())
plt.show()

# %%
def image_format(img):
    img  = img.detach().cpu().numpy()
    img = img.transpose(0,2,3,1)
    img = img * std.reshape(1,1,1,3)
    img = img + mean.reshape(1,1,1,3)
    return img

# %%
# _imgs = image_format(model(X_test[:100].to(device)))

plt.figure(figsize=(10,10))
for _imgid in range(100):
    plt.subplot(10,10,_imgid+1)    

    # plt.subplot(1,3,1)
    # plt.imshow(image_format(X_test[_imgid].reshape(1,3,32,32))[0])

    # plt.subplot(1,3,2)
    plt.imshow(image_format(X_train_noisy[_imgid].reshape(1,3,32,32))[0])

    # plt.subplot(10,3,3)
    # plt.imshow(imgs[_imgid]/imgs[_imgid].max())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11838694141440831..1.0662715066678823].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09015405015008948..1.1131382931270863].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03722512937847855..1.1675281016768047].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.05017176721640393..0.9953699752725238].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12538264800143228..1.0780115153065597].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07305067161423073..1.0311930612078037].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.05103684967715888..1.0033531273081473].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.030760872101170622..1.0465988667582786].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.06908650854646192..1.0756993939080988].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11102914198976566..0.9697259291495657].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07343182445341168..1.0549828106428856].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0868295601701744..1.099259799405416].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10866174112967864..1.0978493256598338].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12268963433416491..1.0014478973742182].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0945272648025981..1.1134914906457656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03797750002265532..1.1113305997934582].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.02043342953729743..0.9993615860870548].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.020263305959365097..0.9918464231244317].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0623403284494104..1.002781538999645].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.17734249382282408..1.1297881294730807].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03807132647681116..1.0326796549559576].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.013451799888727578..0.9233100261076237].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0486986672328002..1.0201092831429488].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.021002397636894765..1.1031741521948675].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1315723475500351..0.9299197201760059].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11298283653251984..0.9886555570260298].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.029869686383808824..1.0223287993691461].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1382739286783975..1.1271547318577986].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.06885436112960652..1.0365362541007395].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0
    nn.ReLU(),
    # nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False),

    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),

    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=3),
    nn.ReLU(),


    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=3),
    nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False),

    nn.ReLU(),

    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),


    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),

    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),
    # UnsharpMask(kernel_size=5, sigma=(1.0, 1.0)),


    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),

    nn.ConvTranspose2d(in_channels=50, out_channels=50, kernel_size=2),
    nn.ReLU(),

    nn.ConvTranspose2d(in_channels=50, out_channels=3, kernel_size=2),
    # UnsharpMask(kernel_size=5, sigma=(1.0, 1.0))


    # nn.Flatten(),
    # nn.Linear(3*32*32, 3*32*32),
    # nn.Unflatten(1,(3,32,32)),
    nn.Tanh()
)


model = nn.Sequential(encoder,decoder).to(device)
model = torch.compile(model)
print(encoder(X_test[:17].to(device)).shape)
print(model(X_test[:17].to(device)).shape)
# Out:
# torch.Size([17, 100, 6, 6])
# torch.Size([17, 3, 32, 32])

# %%
lossfn = nn.MSELoss()

optimizer = optim.Adam(model.parameters(), lr=1e-3, amsgrad=True,decoupled_weight_decay=1e-3)

dataset = TensorDataset(X_train_noisy, X_train)
train_loader = DataLoader(dataset, batch_size=700, shuffle=True)

# %%
epochs = 30
pbar = tqdm(range(epochs), ncols=90, colour="green")

for _ in pbar:
    for Xtnb, Xtb in train_loader:
        Xtnb, Xtb = Xtnb.to(device), Xtb.to(device)
        X_hat = model(Xtb)
        loss = lossfn(X_hat, Xtb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.set_postfix_str(f"loss: {loss*100:.1f}%")
# Out:
# 100%|████████████████████████████████████████| 30/30 [05:19<00:00, 10.65s/it, loss: 20.2%]

# %%
optimizer2 = optim.Adam(model.parameters(), lr=1e-4,amsgrad=True)#,weight_decay=1e-5)
epochs2 = 30
pbar2 = tqdm(range(epochs2), ncols=90, colour="green")

for _ in pbar2:
    for Xtnb2, Xtb2 in train_loader:
        Xtnb2, Xtb2 = Xtnb2.to(device), Xtb2.to(device)
        X_hat2 = model(Xtb2)
        loss2 = lossfn(X_hat2, Xtb2)
        optimizer2.zero_grad()
        loss2.backward()
        optimizer2.step()

        pbar2.set_postfix_str(f"loss: {loss2*100:.1f}%")
# Out:
#  47%|██████████████████▋                     | 14/30 [02:36<02:58, 11.18s/it, loss: 19.0%]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 14
#      11 loss2.backward()
#      12 optimizer2.step()
# ---> 14 pbar2.set_postfix_str(f"loss: {loss2*100:.1f}%")
#
# File ~/.virtualenvs/ml/lib/python3.13/site-packages/torch/_tensor.py:1128, in Tensor.__format__(self, format_spec)
#    1126     return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
#    1127 if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
# -> 1128     return self.item().__format__(format_spec)
#    1129 return object.__format__(self, format_spec)
#
# KeyboardInterrupt:

# %%
_imgs = image_format(model(X_test[:100].to(device)))

_idx = np.random.randint(100,size=3)

plt.figure(figsize=(5,3))
for _imgid,_id in zip(_idx,range(3)):
    plt.subplot(2,3,_id+1)    
    plt.imshow(image_format(X_test_noisy[_imgid].reshape(1,3,32,32))[0])

    plt.subplot(2,3,_id+3+1)
    plt.imshow(_imgs[_imgid]/_imgs[_imgid].max())
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02597038040620786..1.059180848255684].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.15081130649416918..1.0497362670898696].

# %%
_imgs = image_format(model(X_test[:100].to(device)))

_idx = np.random.randint(100,size=3)

plt.figure(figsize=(10,5))
for _imgid,_id in zip(_idx,range(50)):
    plt.subplot(2,3,_id+1)    
    plt.imshow(image_format(X_test_noisy[_imgid].reshape(1,3,32,32))[0])

    plt.subplot(2,3,_id+3+1)
    plt.imshow(_imgs[_imgid]/_imgs[_imgid].max())
plt.show()

# %%
_imgs = image_format(model(X_test[:100].to(device)))

_idx = np.random.randint(100,size=50)

plt.figure(figsize=(10,10))
for _imgid,_id in zip(_idx,range(50)):
    plt.subplot(10,10,2*_id+1)    
    plt.imshow(image_format(X_test_noisy[_imgid].reshape(1,3,32,32))[0])

    plt.subplot(10,10,2*_id+1+1)
    plt.imshow(_imgs[_imgid]/_imgs[_imgid].max())

plt.suptitle("Noisy vs Denoised")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0904882754400701..1.16337421771785].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.032392919315675284..0.9033221520182722].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007179184354448864..1.0790671491720034].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.13649148746520845..1.013683784785104].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.056269087145382646..1.1067052788143739].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.1899515471972461..1.147089036970334].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07911527512921313..1.0749252777980574].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.126686337267775..1.0923393070499097].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03978639075502299..1.107881526314941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03409643385363792..1.0878184227569085].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.042244484816505556..1.0238984035922618].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.13492401405979393..1.1119837488286204].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0664884186569542..1.1581226422434996].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06926460037827475..1.1013153949655679].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10251060979703275..1.0306584766505713].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.011708703143680776..0.9637625439094031].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.011708703143680776..0.9637625439094031].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10814421650563577..0.9142615074668787].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.09033375957924622..1.1302300952844115].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029668071890432968..1.1183135191619926].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02597038040620786..1.059180848255684].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0904882754400701..1.16337421771785].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0888281552471295..1.0097071209487616].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002199680778954105..1.1082736888901303].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.14478938047439627..1.0146822063594616].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.04893749861787583..1.0922388500716909].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007179184354448864..1.0790671491720034].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.060763269922180174..0.9571292602726563].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029668071890432968..1.1183135191619926].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.029008866016739576..1.0280396452667506].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.13492401405979393..1.1119837488286204].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0869657700865396..1.0344289892790781].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.07911527512921313..1.0749252777980574].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.10814421650563577..0.9142615074668787].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.03306186503452957..0.8525523704147102].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.026583449638913015..0.9473094078215305].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.15081130649416918..1.0497362670898696].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1337806570021326..0.9963263882616101].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.028607149844915303..1.142065898744311].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.08119648766465726..1.0049357960255054].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.05097098095759678..1.0345790601736065].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1337806570021326..0.9963263882616101].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.13492401405979393..1.1119837488286204].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09992216862727665..1.027073879647176].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.061477984359155635..1.1142420895732128].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.056269087145382646..1.1067052788143739].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11865759344505822..1.0291305787799352].
